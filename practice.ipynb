# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import nltk
import re
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from collections import Counter

# %%
# !pip install spacy
# !python -m spacy download en_core_web_md
# Out:
# Collecting spacy
#   Downloading spacy-3.8.7-cp311-cp311-macosx_11_0_arm64.whl.metadata (27 kB)
# Collecting spacy-legacy<3.1.0,>=3.0.11 (from spacy)
#   Using cached spacy_legacy-3.0.12-py2.py3-none-any.whl.metadata (2.8 kB)
# Collecting spacy-loggers<2.0.0,>=1.0.0 (from spacy)
#   Using cached spacy_loggers-1.0.5-py3-none-any.whl.metadata (23 kB)
# Collecting murmurhash<1.1.0,>=0.28.0 (from spacy)
#   Downloading murmurhash-1.0.13-cp311-cp311-macosx_11_0_arm64.whl.metadata (2.2 kB)
# Collecting cymem<2.1.0,>=2.0.2 (from spacy)
#   Downloading cymem-2.0.11-cp311-cp311-macosx_11_0_arm64.whl.metadata (8.5 kB)
# Collecting preshed<3.1.0,>=3.0.2 (from spacy)
#   Downloading preshed-3.0.10-cp311-cp311-macosx_11_0_arm64.whl.metadata (2.4 kB)
# Collecting thinc<8.4.0,>=8.3.4 (from spacy)
#   Downloading thinc-8.3.6-cp311-cp311-macosx_11_0_arm64.whl.metadata (15 kB)
# Collecting wasabi<1.2.0,>=0.9.1 (from spacy)
#   Using cached wasabi-1.1.3-py3-none-any.whl.metadata (28 kB)
# Collecting srsly<3.0.0,>=2.4.3 (from spacy)
#   Downloading srsly-2.5.1-cp311-cp311-macosx_11_0_arm64.whl.metadata (19 kB)
# Collecting catalogue<2.1.0,>=2.0.6 (from spacy)
#   Using cached catalogue-2.0.10-py3-none-any.whl.metadata (14 kB)
# Collecting weasel<0.5.0,>=0.1.0 (from spacy)
#   Using cached weasel-0.4.1-py3-none-any.whl.metadata (4.6 kB)
# Collecting typer<1.0.0,>=0.3.0 (from spacy)
#   Downloading typer-0.16.0-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /Users/vishal/Downloads/Projects/data_science_krishnaik/code/kn_env/lib/python3.11/site-packages (from spacy) (4.67.1)
# Requirement already satisfied: numpy>=1.19.0 in /Users/vishal/Downloads/Projects/data_science_krishnaik/code/kn_env/lib/python3.11/site-packages (from spacy) (2.1.3)
# Collecting requests<3.0.0,>=2.13.0 (from spacy)
#   Using cached requests-2.32.3-py3-none-any.whl.metadata (4.6 kB)
# Collecting pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 (from spacy)
#   Downloading pydantic-2.11.5-py3-none-any.whl.metadata (67 kB)
# Collecting jinja2 (from spacy)
#   Using cached jinja2-3.1.6-py3-none-any.whl.metadata (2.9 kB)
# Requirement already satisfied: setuptools in /Users/vishal/Downloads/Projects/data_science_krishnaik/code/kn_env/lib/python3.11/site-packages (from spacy) (75.5.0)
# Requirement already satisfied: packaging>=20.0 in /Users/vishal/Downloads/Projects/data_science_krishnaik/code/kn_env/lib/python3.11/site-packages (from spacy) (24.2)
# Collecting langcodes<4.0.0,>=3.2.0 (from spacy)
#   Downloading langcodes-3.5.0-py3-none-any.whl.metadata (29 kB)
# Collecting language-data>=1.2 (from langcodes<4.0.0,>=3.2.0->spacy)
#   Downloading language_data-1.3.0-py3-none-any.whl.metadata (4.3 kB)
# Collecting annotated-types>=0.6.0 (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy)
#   Using cached annotated_types-0.7.0-py3-none-any.whl.metadata (15 kB)
# Collecting pydantic-core==2.33.2 (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy)
#   Downloading pydantic_core-2.33.2-cp311-cp311-macosx_11_0_arm64.whl.metadata (6.8 kB)
# Requirement already satisfied: typing-extensions>=4.12.2 in /Users/vishal/Downloads/Projects/data_science_krishnaik/code/kn_env/lib/python3.11/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (4.12.2)
# Collecting typing-inspection>=0.4.0 (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy)
#   Downloading typing_inspection-0.4.1-py3-none-any.whl.metadata (2.6 kB)
# Collecting charset-normalizer<4,>=2 (from requests<3.0.0,>=2.13.0->spacy)
#   Using cached charset_normalizer-3.4.2-cp311-cp311-macosx_10_9_universal2.whl.metadata (35 kB)
# Collecting idna<4,>=2.5 (from requests<3.0.0,>=2.13.0->spacy)
#   Using cached idna-3.10-py3-none-any.whl.metadata (10 kB)
# Collecting urllib3<3,>=1.21.1 (from requests<3.0.0,>=2.13.0->spacy)
#   Using cached urllib3-2.4.0-py3-none-any.whl.metadata (6.5 kB)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/vishal/Downloads/Projects/data_science_krishnaik/code/kn_env/lib/python3.11/site-packages (from requests<3.0.0,>=2.13.0->spacy) (2025.4.26)
# Collecting blis<1.4.0,>=1.3.0 (from thinc<8.4.0,>=8.3.4->spacy)
#   Downloading blis-1.3.0-cp311-cp311-macosx_11_0_arm64.whl.metadata (7.4 kB)
# Collecting confection<1.0.0,>=0.0.1 (from thinc<8.4.0,>=8.3.4->spacy)
#   Using cached confection-0.1.5-py3-none-any.whl.metadata (19 kB)
# Requirement already satisfied: click>=8.0.0 in /Users/vishal/Downloads/Projects/data_science_krishnaik/code/kn_env/lib/python3.11/site-packages (from typer<1.0.0,>=0.3.0->spacy) (8.2.1)
# Collecting shellingham>=1.3.0 (from typer<1.0.0,>=0.3.0->spacy)
#   Using cached shellingham-1.5.4-py2.py3-none-any.whl.metadata (3.5 kB)
# Collecting rich>=10.11.0 (from typer<1.0.0,>=0.3.0->spacy)
#   Downloading rich-14.0.0-py3-none-any.whl.metadata (18 kB)
# Collecting cloudpathlib<1.0.0,>=0.7.0 (from weasel<0.5.0,>=0.1.0->spacy)
#   Downloading cloudpathlib-0.21.1-py3-none-any.whl.metadata (14 kB)
# Collecting smart-open<8.0.0,>=5.2.1 (from weasel<0.5.0,>=0.1.0->spacy)
#   Downloading smart_open-7.1.0-py3-none-any.whl.metadata (24 kB)
# Collecting MarkupSafe>=2.0 (from jinja2->spacy)
#   Using cached MarkupSafe-3.0.2-cp311-cp311-macosx_11_0_arm64.whl.metadata (4.0 kB)
# Collecting marisa-trie>=1.1.0 (from language-data>=1.2->langcodes<4.0.0,>=3.2.0->spacy)
#   Downloading marisa_trie-1.2.1-cp311-cp311-macosx_11_0_arm64.whl.metadata (9.0 kB)
# Collecting markdown-it-py>=2.2.0 (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy)
#   Using cached markdown_it_py-3.0.0-py3-none-any.whl.metadata (6.9 kB)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /Users/vishal/Downloads/Projects/data_science_krishnaik/code/kn_env/lib/python3.11/site-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy) (2.18.0)
# Collecting wrapt (from smart-open<8.0.0,>=5.2.1->weasel<0.5.0,>=0.1.0->spacy)
#   Downloading wrapt-1.17.2-cp311-cp311-macosx_11_0_arm64.whl.metadata (6.4 kB)
# Collecting mdurl~=0.1 (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy)
#   Using cached mdurl-0.1.2-py3-none-any.whl.metadata (1.6 kB)
# Downloading spacy-3.8.7-cp311-cp311-macosx_11_0_arm64.whl (6.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.4/6.4 MB 5.5 MB/s eta 0:00:00a 0:00:01
# Using cached catalogue-2.0.10-py3-none-any.whl (17 kB)
# Downloading cymem-2.0.11-cp311-cp311-macosx_11_0_arm64.whl (41 kB)
# Downloading langcodes-3.5.0-py3-none-any.whl (182 kB)
# Downloading murmurhash-1.0.13-cp311-cp311-macosx_11_0_arm64.whl (26 kB)
# Downloading preshed-3.0.10-cp311-cp311-macosx_11_0_arm64.whl (127 kB)
# Downloading pydantic-2.11.5-py3-none-any.whl (444 kB)
# Downloading pydantic_core-2.33.2-cp311-cp311-macosx_11_0_arm64.whl (1.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 5.5 MB/s eta 0:00:00a 0:00:01
# Using cached requests-2.32.3-py3-none-any.whl (64 kB)
# Using cached spacy_legacy-3.0.12-py2.py3-none-any.whl (29 kB)
# Using cached spacy_loggers-1.0.5-py3-none-any.whl (22 kB)
# Downloading srsly-2.5.1-cp311-cp311-macosx_11_0_arm64.whl (634 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 634.4/634.4 kB 5.2 MB/s eta 0:00:00
# Downloading thinc-8.3.6-cp311-cp311-macosx_11_0_arm64.whl (845 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 845.3/845.3 kB 5.2 MB/s eta 0:00:00
# Downloading typer-0.16.0-py3-none-any.whl (46 kB)
# Using cached wasabi-1.1.3-py3-none-any.whl (27 kB)
# Using cached weasel-0.4.1-py3-none-any.whl (50 kB)
# Using cached jinja2-3.1.6-py3-none-any.whl (134 kB)
# Using cached annotated_types-0.7.0-py3-none-any.whl (13 kB)
# Downloading blis-1.3.0-cp311-cp311-macosx_11_0_arm64.whl (1.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 5.4 MB/s eta 0:00:00a 0:00:01
# Using cached charset_normalizer-3.4.2-cp311-cp311-macosx_10_9_universal2.whl (198 kB)
# Downloading cloudpathlib-0.21.1-py3-none-any.whl (52 kB)
# Using cached confection-0.1.5-py3-none-any.whl (35 kB)
# Using cached idna-3.10-py3-none-any.whl (70 kB)
# Downloading language_data-1.3.0-py3-none-any.whl (5.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.4/5.4 MB 5.6 MB/s eta 0:00:00a 0:00:01
# Using cached MarkupSafe-3.0.2-cp311-cp311-macosx_11_0_arm64.whl (12 kB)
# Downloading rich-14.0.0-py3-none-any.whl (243 kB)
# Using cached shellingham-1.5.4-py2.py3-none-any.whl (9.8 kB)
# Downloading smart_open-7.1.0-py3-none-any.whl (61 kB)
# Downloading typing_inspection-0.4.1-py3-none-any.whl (14 kB)
# Using cached urllib3-2.4.0-py3-none-any.whl (128 kB)
# Downloading marisa_trie-1.2.1-cp311-cp311-macosx_11_0_arm64.whl (174 kB)
# Using cached markdown_it_py-3.0.0-py3-none-any.whl (87 kB)
# Downloading wrapt-1.17.2-cp311-cp311-macosx_11_0_arm64.whl (38 kB)
# Using cached mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Installing collected packages: cymem, wrapt, wasabi, urllib3, typing-inspection, spacy-loggers, spacy-legacy, shellingham, pydantic-core, murmurhash, mdurl, MarkupSafe, marisa-trie, idna, cloudpathlib, charset-normalizer, catalogue, blis, annotated-types, srsly, smart-open, requests, pydantic, preshed, markdown-it-py, language-data, jinja2, rich, langcodes, confection, typer, thinc, weasel, spacy
# Successfully installed MarkupSafe-3.0.2 annotated-types-0.7.0 blis-1.3.0 catalogue-2.0.10 charset-normalizer-3.4.2 cloudpathlib-0.21.1 confection-0.1.5 cymem-2.0.11 idna-3.10 jinja2-3.1.6 langcodes-3.5.0 language-data-1.3.0 marisa-trie-1.2.1 markdown-it-py-3.0.0 mdurl-0.1.2 murmurhash-1.0.13 preshed-3.0.10 pydantic-2.11.5 pydantic-core-2.33.2 requests-2.32.3 rich-14.0.0 shellingham-1.5.4 smart-open-7.1.0 spacy-3.8.7 spacy-legacy-3.0.12 spacy-loggers-1.0.5 srsly-2.5.1 thinc-8.3.6 typer-0.16.0 typing-inspection-0.4.1 urllib3-2.4.0 wasabi-1.1.3 weasel-0.4.1 wrapt-1.17.2
# Collecting en-core-web-md==3.8.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_md-3.8.0/en_core_web_md-3.8.0-py3-none-any.whl (33.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 33.5/33.5 MB 5.6 MB/s eta 0:00:00a 0:00:01
# Installing collected packages: en-core-web-md
# Successfully installed en-core-web-md-3.8.0
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_md')

# %%
fake_news=pd.read_csv('Fake.csv')
real_news=pd.read_csv('True.csv')

# %%
fake_news
# Out:
#                                                    title  \
# 0       Donald Trump Sends Out Embarrassing New Year’...
# 1       Drunk Bragging Trump Staffer Started Russian ...
# 2       Sheriff David Clarke Becomes An Internet Joke...
# 3       Trump Is So Obsessed He Even Has Obama’s Name...
# 4       Pope Francis Just Called Out Donald Trump Dur...
# ...                                                  ...
# 23476  McPain: John McCain Furious That Iran Treated ...
# 23477  JUSTICE? Yahoo Settles E-mail Privacy Class-ac...
# 23478  Sunnistan: US and Allied ‘Safe Zone’ Plan to T...
# 23479  How to Blow $700 Million: Al Jazeera America F...
# 23480  10 U.S. Navy Sailors Held by Iranian Military ...
#
#                                                     text      subject  \
# 0      Donald Trump just couldn t wish all Americans ...         News
# 1      House Intelligence Committee Chairman Devin Nu...         News
# 2      On Friday, it was revealed that former Milwauk...         News
# 3      On Christmas day, Donald Trump announced that ...         News
# 4      Pope Francis used his annual Christmas Day mes...         News
# ...                                                  ...          ...
# 23476  21st Century Wire says As 21WIRE reported earl...  Middle-east
# 23477  21st Century Wire says It s a familiar theme. ...  Middle-east
# 23478  Patrick Henningsen  21st Century WireRemember ...  Middle-east
# 23479  21st Century Wire says Al Jazeera America will...  Middle-east
# 23480  21st Century Wire says As 21WIRE predicted in ...  Middle-east
#
#                     date
# 0      December 31, 2017
# 1      December 31, 2017
# 2      December 30, 2017
# 3      December 29, 2017
# 4      December 25, 2017
# ...                  ...
# 23476   January 16, 2016
# 23477   January 16, 2016
# 23478   January 15, 2016
# 23479   January 14, 2016
# 23480   January 12, 2016
#
# [23481 rows x 4 columns]

# %%
fake_news['label']=0
real_news['label']=1
real_news
# Out:
#                                                    title  \
# 0      As U.S. budget fight looms, Republicans flip t...
# 1      U.S. military to accept transgender recruits o...
# 2      Senior U.S. Republican senator: 'Let Mr. Muell...
# 3      FBI Russia probe helped by Australian diplomat...
# 4      Trump wants Postal Service to charge 'much mor...
# ...                                                  ...
# 21412  'Fully committed' NATO backs new U.S. approach...
# 21413  LexisNexis withdrew two products from Chinese ...
# 21414  Minsk cultural hub becomes haven from authorities
# 21415  Vatican upbeat on possibility of Pope Francis ...
# 21416  Indonesia to buy $1.14 billion worth of Russia...
#
#                                                     text       subject  \
# 0      WASHINGTON (Reuters) - The head of a conservat...  politicsNews
# 1      WASHINGTON (Reuters) - Transgender people will...  politicsNews
# 2      WASHINGTON (Reuters) - The special counsel inv...  politicsNews
# 3      WASHINGTON (Reuters) - Trump campaign adviser ...  politicsNews
# 4      SEATTLE/WASHINGTON (Reuters) - President Donal...  politicsNews
# ...                                                  ...           ...
# 21412  BRUSSELS (Reuters) - NATO allies on Tuesday we...     worldnews
# 21413  LONDON (Reuters) - LexisNexis, a provider of l...     worldnews
# 21414  MINSK (Reuters) - In the shadow of disused Sov...     worldnews
# 21415  MOSCOW (Reuters) - Vatican Secretary of State ...     worldnews
# 21416  JAKARTA (Reuters) - Indonesia will buy 11 Sukh...     worldnews
#
#                      date  label
# 0      December 31, 2017       1
# 1      December 29, 2017       1
# 2      December 31, 2017       1
# 3      December 30, 2017       1
# 4      December 29, 2017       1
# ...                   ...    ...
# 21412    August 22, 2017       1
# 21413    August 22, 2017       1
# 21414    August 22, 2017       1
# 21415    August 22, 2017       1
# 21416    August 22, 2017       1
#
# [21417 rows x 5 columns]

# %%
shape_fake=fake_news.shape
shape_real=real_news.shape
print(f"Fake news shape: {shape_fake}")
print(f"Real news shape: {shape_real}")
# Out:
# Fake news shape: (23481, 5)
# Real news shape: (21417, 5)

# %%
df = pd.concat([fake_news, real_news], ignore_index=True)
df
# Out:
#                                                    title  \
# 0       Donald Trump Sends Out Embarrassing New Year’...
# 1       Drunk Bragging Trump Staffer Started Russian ...
# 2       Sheriff David Clarke Becomes An Internet Joke...
# 3       Trump Is So Obsessed He Even Has Obama’s Name...
# 4       Pope Francis Just Called Out Donald Trump Dur...
# ...                                                  ...
# 44893  'Fully committed' NATO backs new U.S. approach...
# 44894  LexisNexis withdrew two products from Chinese ...
# 44895  Minsk cultural hub becomes haven from authorities
# 44896  Vatican upbeat on possibility of Pope Francis ...
# 44897  Indonesia to buy $1.14 billion worth of Russia...
#
#                                                     text    subject  \
# 0      Donald Trump just couldn t wish all Americans ...       News
# 1      House Intelligence Committee Chairman Devin Nu...       News
# 2      On Friday, it was revealed that former Milwauk...       News
# 3      On Christmas day, Donald Trump announced that ...       News
# 4      Pope Francis used his annual Christmas Day mes...       News
# ...                                                  ...        ...
# 44893  BRUSSELS (Reuters) - NATO allies on Tuesday we...  worldnews
# 44894  LONDON (Reuters) - LexisNexis, a provider of l...  worldnews
# 44895  MINSK (Reuters) - In the shadow of disused Sov...  worldnews
# 44896  MOSCOW (Reuters) - Vatican Secretary of State ...  worldnews
# 44897  JAKARTA (Reuters) - Indonesia will buy 11 Sukh...  worldnews
#
#                     date  label
# 0      December 31, 2017      0
# 1      December 31, 2017      0
# 2      December 30, 2017      0
# 3      December 29, 2017      0
# 4      December 25, 2017      0
# ...                  ...    ...
# 44893   August 22, 2017       1
# 44894   August 22, 2017       1
# 44895   August 22, 2017       1
# 44896   August 22, 2017       1
# 44897   August 22, 2017       1
#
# [44898 rows x 5 columns]

# %%
print(df['label'].value_counts())

sns.countplot(data=df, x='label')
plt.title("Real vs Fake News Count")
plt.show()
# Out:
# label
# 0    23481
# 1    21417
# Name: count, dtype: int64

# %%
df=df.dropna()

# %%
df['label'].value_counts()
# Out:
# label
# 0    23481
# 1    21417
# Name: count, dtype: int64

# %%
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer, HashingVectorizer

# %%
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/vishal/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %%
from nltk.corpus import stopwords
from nltk.stem.porter import PorterStemmer
ps = PorterStemmer()
corpus = []
for i in range(0, len(df)):
    review = re.sub('[^a-zA-Z]', ' ', df['text'][i])
    review = review.lower()
    review = review.split()
    
    review = [ps.stem(word) for word in review if not word in stopwords.words('english')]
    review = ' '.join(review)
    corpus.append(review)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[14], line 10
#       7 review = review.lower()
#       8 review = review.split()
# ---> 10 review = [ps.stem(word) for word in review if not word in stopwords.words('english')]
#      11 review = ' '.join(review)
#      12 corpus.append(review)
#
# Cell In[14], line 10, in <listcomp>(.0)
#       7 review = review.lower()
#       8 review = review.split()
# ---> 10 review = [ps.stem(word) for word in review if not word in stopwords.words('english')]
#      11 review = ' '.join(review)
#      12 corpus.append(review)
#
# File ~/Downloads/Projects/data_science_krishnaik/code/kn_env/lib/python3.11/site-packages/nltk/corpus/reader/wordlist.py:21, in WordListCorpusReader.words(self, fileids, ignore_lines_startswith)
#      18 def words(self, fileids=None, ignore_lines_startswith="\n"):
#      19     return [
#      20         line
# ---> 21         for line in line_tokenize(self.raw(fileids))
#      22         if not line.startswith(ignore_lines_startswith)
#      23     ]
#
# File ~/Downloads/Projects/data_science_krishnaik/code/kn_env/lib/python3.11/site-packages/nltk/tokenize/simple.py:139, in line_tokenize(text, blanklines)
#     138 def line_tokenize(text, blanklines="discard"):
# --> 139     return LineTokenizer(blanklines).tokenize(text)
#
# File ~/Downloads/Projects/data_science_krishnaik/code/kn_env/lib/python3.11/site-packages/nltk/tokenize/simple.py:118, in LineTokenizer.tokenize(self, s)
#     116 # If requested, strip off blank lines.
#     117 if self._blanklines == "discard":
# --> 118     lines = [l for l in lines if l.rstrip()]
#     119 elif self._blanklines == "discard-eof":
#     120     if lines and not lines[-1].strip():
#
# File ~/Downloads/Projects/data_science_krishnaik/code/kn_env/lib/python3.11/site-packages/nltk/tokenize/simple.py:118, in <listcomp>(.0)
#     116 # If requested, strip off blank lines.
#     117 if self._blanklines == "discard":
# --> 118     lines = [l for l in lines if l.rstrip()]
#     119 elif self._blanklines == "discard-eof":
#     120     if lines and not lines[-1].strip():
#
# KeyboardInterrupt:

# %%
# !pip install spacy-transformers
# !pip install spacy-curated-transformers
# !python -m spacy download en_core_web_trf
# Out:
# python(58293) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Requirement already satisfied: spacy-transformers in /Users/vishal/Downloads/Projects/data_science_krishnaik/code/kn_env/lib/python3.11/site-packages (1.3.9)
# Requirement already satisfied: spacy<4.1.0,>=3.5.0 in /Users/vishal/Downloads/Projects/data_science_krishnaik/code/kn_env/lib/python3.11/site-packages (from spacy-transformers) (3.8.7)
# Requirement already satisfied: numpy>=1.19.0 in /Users/vishal/Downloads/Projects/data_science_krishnaik/code/kn_env/lib/python3.11/site-packages (from spacy-transformers) (2.1.3)
# Requirement already satisfied: transformers<4.50.0,>=3.4.0 in /Users/vishal/Downloads/Projects/data_science_krishnaik/code/kn_env/lib/python3.11/site-packages (from spacy-transformers) (4.49.0)
# Requirement already satisfied: torch>=1.8.0 in /Users/vishal/Downloads/Projects/data_science_krishnaik/code/kn_env/lib/python3.11/site-packages (from spacy-transformers) (2.7.0)
# Requirement already satisfied: srsly<3.0.0,>=2.4.0 in /Users/vishal/Downloads/Projects/data_science_krishnaik/code/kn_env/lib/python3.11/site-packages (from spacy-transformers) (2.5.1)
# Requirement already satisfied: spacy-alignments<1.0.0,>=0.7.2 in /Users/vishal/Downloads/Projects/data_science_krishnaik/code/kn_env/lib/python3.11/site-packages (from spacy-transformers) (0.9.1)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /Users/vishal/Downloads/Projects/data_science_krishnaik/code/kn_env/lib/python3.11/site-packages (from spacy<4.1.0,>=3.5.0->spacy-transformers) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /Users/vishal/Downloads/Projects/data_science_krishnaik/code/kn_env/lib/python3.11/site-packages (from spacy<4.1.0,>=3.5.0->spacy-transformers) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /Users/vishal/Downloads/Projects/data_science_krishnaik/code/kn_env/lib/python3.11/site-packages (from spacy<4.1.0,>=3.5.0->spacy-transformers) (1.0.13)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /Users/vishal/Downloads/Projects/data_science_krishnaik/code/kn_env/lib/python3.11/site-packages (from spacy<4.1.0,>=3.5.0->spacy-transformers) (2.0.11)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /Users/vishal/Downloads/Projects/data_science_krishnaik/code/kn_env/lib/python3.11/site-packages (from spacy<4.1.0,>=3.5.0->spacy-transformers) (3.0.10)
# Requirement already satisfied: thinc<8.4.0,>=8.3.4 in /Users/vishal/Downloads/Projects/data_science_krishnaik/code/kn_env/lib/python3.11/site-packages (from spacy<4.1.0,>=3.5.0->spacy-transformers) (8.3.6)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /Users/vishal/Downloads/Projects/data_science_krishnaik/code/kn_env/lib/python3.11/site-packages (from spacy<4.1.0,>=3.5.0->spacy-transformers) (1.1.3)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /Users/vishal/Downloads/Projects/data_science_krishnaik/code/kn_env/lib/python3.11/site-packages (from spacy<4.1.0,>=3.5.0->spacy-transformers) (2.0.10)
# Requirement already satisfied: weasel<0.5.0,>=0.1.0 in /Users/vishal/Downloads/Projects/data_science_krishnaik/code/kn_env/lib/python3.11/site-packages (from spacy<4.1.0,>=3.5.0->spacy-transformers) (0.4.1)
# Requirement already satisfied: typer<1.0.0,>=0.3.0 in /Users/vishal/Downloads/Projects/data_science_krishnaik/code/kn_env/lib/python3.11/site-packages (from spacy<4.1.0,>=3.5.0->spacy-transformers) (0.16.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /Users/vishal/Downloads/Projects/data_science_krishnaik/code/kn_env/lib/python3.11/site-packages (from spacy<4.1.0,>=3.5.0->spacy-transformers) (4.67.1)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /Users/vishal/Downloads/Projects/data_science_krishnaik/code/kn_env/lib/python3.11/site-packages (from spacy<4.1.0,>=3.5.0->spacy-transformers) (2.32.3)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /Users/vishal/Downloads/Projects/data_science_krishnaik/code/kn_env/lib/python3.11/site-packages (from spacy<4.1.0,>=3.5.0->spacy-transformers) (2.11.5)
# Requirement already satisfied: jinja2 in /Users/vishal/Downloads/Projects/data_science_krishnaik/code/kn_env/lib/python3.11/site-packages (from spacy<4.1.0,>=3.5.0->spacy-transformers) (3.1.6)
# Requirement already satisfied: setuptools in /Users/vishal/Downloads/Projects/data_science_krishnaik/code/kn_env/lib/python3.11/site-packages (from spacy<4.1.0,>=3.5.0->spacy-transformers) (75.5.0)
# Requirement already satisfied: packaging>=20.0 in /Users/vishal/Downloads/Projects/data_science_krishnaik/code/kn_env/lib/python3.11/site-packages (from spacy<4.1.0,>=3.5.0->spacy-transformers) (24.2)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /Users/vishal/Downloads/Projects/data_science_krishnaik/code/kn_env/lib/python3.11/site-packages (from spacy<4.1.0,>=3.5.0->spacy-transformers) (3.5.0)
# Requirement already satisfied: filelock in /Users/vishal/Downloads/Projects/data_science_krishnaik/code/kn_env/lib/python3.11/site-packages (from torch>=1.8.0->spacy-transformers) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /Users/vishal/Downloads/Projects/data_science_krishnaik/code/kn_env/lib/python3.11/site-packages (from torch>=1.8.0->spacy-transformers) (4.12.2)
# Requirement already satisfied: sympy>=1.13.3 in /Users/vishal/Downloads/Projects/data_science_krishnaik/code/kn_env/lib/python3.11/site-packages (from torch>=1.8.0->spacy-transformers) (1.14.0)
# Requirement already satisfied: networkx in /Users/vishal/Downloads/Projects/data_science_krishnaik/code/kn_env/lib/python3.11/site-packages (from torch>=1.8.0->spacy-transformers) (3.4.2)
# Requirement already satisfied: fsspec in /Users/vishal/Downloads/Projects/data_science_krishnaik/code/kn_env/lib/python3.11/site-packages (from torch>=1.8.0->spacy-transformers) (2025.5.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.26.0 in /Users/vishal/Downloads/Projects/data_science_krishnaik/code/kn_env/lib/python3.11/site-packages (from transformers<4.50.0,>=3.4.0->spacy-transformers) (0.32.2)
# Requirement already satisfied: pyyaml>=5.1 in /Users/vishal/Downloads/Projects/data_science_krishnaik/code/kn_env/lib/python3.11/site-packages (from transformers<4.50.0,>=3.4.0->spacy-transformers) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /Users/vishal/Downloads/Projects/data_science_krishnaik/code/kn_env/lib/python3.11/site-packages (from transformers<4.50.0,>=3.4.0->spacy-transformers) (2024.11.6)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /Users/vishal/Downloads/Projects/data_science_krishnaik/code/kn_env/lib/python3.11/site-packages (from transformers<4.50.0,>=3.4.0->spacy-transformers) (0.21.1)
# Requirement already satisfied: safetensors>=0.4.1 in /Users/vishal/Downloads/Projects/data_science_krishnaik/code/kn_env/lib/python3.11/site-packages (from transformers<4.50.0,>=3.4.0->spacy-transformers) (0.5.3)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.2 in /Users/vishal/Downloads/Projects/data_science_krishnaik/code/kn_env/lib/python3.11/site-packages (from huggingface-hub<1.0,>=0.26.0->transformers<4.50.0,>=3.4.0->spacy-transformers) (1.1.2)
# Requirement already satisfied: language-data>=1.2 in /Users/vishal/Downloads/Projects/data_science_krishnaik/code/kn_env/lib/python3.11/site-packages (from langcodes<4.0.0,>=3.2.0->spacy<4.1.0,>=3.5.0->spacy-transformers) (1.3.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/vishal/Downloads/Projects/data_science_krishnaik/code/kn_env/lib/python3.11/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<4.1.0,>=3.5.0->spacy-transformers) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /Users/vishal/Downloads/Projects/data_science_krishnaik/code/kn_env/lib/python3.11/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<4.1.0,>=3.5.0->spacy-transformers) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /Users/vishal/Downloads/Projects/data_science_krishnaik/code/kn_env/lib/python3.11/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<4.1.0,>=3.5.0->spacy-transformers) (0.4.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/vishal/Downloads/Projects/data_science_krishnaik/code/kn_env/lib/python3.11/site-packages (from requests<3.0.0,>=2.13.0->spacy<4.1.0,>=3.5.0->spacy-transformers) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /Users/vishal/Downloads/Projects/data_science_krishnaik/code/kn_env/lib/python3.11/site-packages (from requests<3.0.0,>=2.13.0->spacy<4.1.0,>=3.5.0->spacy-transformers) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/vishal/Downloads/Projects/data_science_krishnaik/code/kn_env/lib/python3.11/site-packages (from requests<3.0.0,>=2.13.0->spacy<4.1.0,>=3.5.0->spacy-transformers) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/vishal/Downloads/Projects/data_science_krishnaik/code/kn_env/lib/python3.11/site-packages (from requests<3.0.0,>=2.13.0->spacy<4.1.0,>=3.5.0->spacy-transformers) (2025.4.26)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /Users/vishal/Downloads/Projects/data_science_krishnaik/code/kn_env/lib/python3.11/site-packages (from sympy>=1.13.3->torch>=1.8.0->spacy-transformers) (1.3.0)
# Requirement already satisfied: blis<1.4.0,>=1.3.0 in /Users/vishal/Downloads/Projects/data_science_krishnaik/code/kn_env/lib/python3.11/site-packages (from thinc<8.4.0,>=8.3.4->spacy<4.1.0,>=3.5.0->spacy-transformers) (1.3.0)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /Users/vishal/Downloads/Projects/data_science_krishnaik/code/kn_env/lib/python3.11/site-packages (from thinc<8.4.0,>=8.3.4->spacy<4.1.0,>=3.5.0->spacy-transformers) (0.1.5)
# Requirement already satisfied: click>=8.0.0 in /Users/vishal/Downloads/Projects/data_science_krishnaik/code/kn_env/lib/python3.11/site-packages (from typer<1.0.0,>=0.3.0->spacy<4.1.0,>=3.5.0->spacy-transformers) (8.2.1)
# Requirement already satisfied: shellingham>=1.3.0 in /Users/vishal/Downloads/Projects/data_science_krishnaik/code/kn_env/lib/python3.11/site-packages (from typer<1.0.0,>=0.3.0->spacy<4.1.0,>=3.5.0->spacy-transformers) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in /Users/vishal/Downloads/Projects/data_science_krishnaik/code/kn_env/lib/python3.11/site-packages (from typer<1.0.0,>=0.3.0->spacy<4.1.0,>=3.5.0->spacy-transformers) (14.0.0)
# Requirement already satisfied: cloudpathlib<1.0.0,>=0.7.0 in /Users/vishal/Downloads/Projects/data_science_krishnaik/code/kn_env/lib/python3.11/site-packages (from weasel<0.5.0,>=0.1.0->spacy<4.1.0,>=3.5.0->spacy-transformers) (0.21.1)
# Requirement already satisfied: smart-open<8.0.0,>=5.2.1 in /Users/vishal/Downloads/Projects/data_science_krishnaik/code/kn_env/lib/python3.11/site-packages (from weasel<0.5.0,>=0.1.0->spacy<4.1.0,>=3.5.0->spacy-transformers) (7.1.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/vishal/Downloads/Projects/data_science_krishnaik/code/kn_env/lib/python3.11/site-packages (from jinja2->spacy<4.1.0,>=3.5.0->spacy-transformers) (3.0.2)
# Requirement already satisfied: marisa-trie>=1.1.0 in /Users/vishal/Downloads/Projects/data_science_krishnaik/code/kn_env/lib/python3.11/site-packages (from language-data>=1.2->langcodes<4.0.0,>=3.2.0->spacy<4.1.0,>=3.5.0->spacy-transformers) (1.2.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /Users/vishal/Downloads/Projects/data_science_krishnaik/code/kn_env/lib/python3.11/site-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy<4.1.0,>=3.5.0->spacy-transformers) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /Users/vishal/Downloads/Projects/data_science_krishnaik/code/kn_env/lib/python3.11/site-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy<4.1.0,>=3.5.0->spacy-transformers) (2.18.0)
# Requirement already satisfied: wrapt in /Users/vishal/Downloads/Projects/data_science_krishnaik/code/kn_env/lib/python3.11/site-packages (from smart-open<8.0.0,>=5.2.1->weasel<0.5.0,>=0.1.0->spacy<4.1.0,>=3.5.0->spacy-transformers) (1.17.2)
# Requirement already satisfied: mdurl~=0.1 in /Users/vishal/Downloads/Projects/data_science_krishnaik/code/kn_env/lib/python3.11/site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy<4.1.0,>=3.5.0->spacy-transformers) (0.1.2)
# python(58294) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Requirement already satisfied: spacy-curated-transformers in /Users/vishal/Downloads/Projects/data_science_krishnaik/code/kn_env/lib/python3.11/site-packages (0.3.0)
# Requirement already satisfied: curated-transformers<0.2.0,>=0.1.0 in /Users/vishal/Downloads/Projects/data_science_krishnaik/code/kn_env/lib/python3.11/site-packages (from spacy-curated-transformers) (0.1.1)
# Requirement already satisfied: curated-tokenizers<0.1.0,>=0.0.9 in /Users/vishal/Downloads/Projects/data_science_krishnaik/code/kn_env/lib/python3.11/site-packages (from spacy-curated-transformers) (0.0.9)
# Requirement already satisfied: torch>=1.12.0 in /Users/vishal/Downloads/Projects/data_science_krishnaik/code/kn_env/lib/python3.11/site-packages (from spacy-curated-transformers) (2.7.0)
# Requirement already satisfied: regex>=2022 in /Users/vishal/Downloads/Projects/data_science_krishnaik/code/kn_env/lib/python3.11/site-packages (from curated-tokenizers<0.1.0,>=0.0.9->spacy-curated-transformers) (2024.11.6)
# Requirement already satisfied: filelock in /Users/vishal/Downloads/Projects/data_science_krishnaik/code/kn_env/lib/python3.11/site-packages (from torch>=1.12.0->spacy-curated-transformers) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /Users/vishal/Downloads/Projects/data_science_krishnaik/code/kn_env/lib/python3.11/site-packages (from torch>=1.12.0->spacy-curated-transformers) (4.12.2)
# Requirement already satisfied: sympy>=1.13.3 in /Users/vishal/Downloads/Projects/data_science_krishnaik/code/kn_env/lib/python3.11/site-packages (from torch>=1.12.0->spacy-curated-transformers) (1.14.0)
# Requirement already satisfied: networkx in /Users/vishal/Downloads/Projects/data_science_krishnaik/code/kn_env/lib/python3.11/site-packages (from torch>=1.12.0->spacy-curated-transformers) (3.4.2)
# Requirement already satisfied: jinja2 in /Users/vishal/Downloads/Projects/data_science_krishnaik/code/kn_env/lib/python3.11/site-packages (from torch>=1.12.0->spacy-curated-transformers) (3.1.6)
# Requirement already satisfied: fsspec in /Users/vishal/Downloads/Projects/data_science_krishnaik/code/kn_env/lib/python3.11/site-packages (from torch>=1.12.0->spacy-curated-transformers) (2025.5.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /Users/vishal/Downloads/Projects/data_science_krishnaik/code/kn_env/lib/python3.11/site-packages (from sympy>=1.13.3->torch>=1.12.0->spacy-curated-transformers) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/vishal/Downloads/Projects/data_science_krishnaik/code/kn_env/lib/python3.11/site-packages (from jinja2->torch>=1.12.0->spacy-curated-transformers) (3.0.2)
# python(58295) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Collecting en-core-web-trf==3.8.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_trf-3.8.0/en_core_web_trf-3.8.0-py3-none-any.whl (457.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 457.4/457.4 MB 5.4 MB/s eta 0:00:0000:0100:03
# Requirement already satisfied: spacy-curated-transformers<1.0.0,>=0.2.2 in /Users/vishal/Downloads/Projects/data_science_krishnaik/code/kn_env/lib/python3.11/site-packages (from en-core-web-trf==3.8.0) (0.3.0)
# Requirement already satisfied: curated-transformers<0.2.0,>=0.1.0 in /Users/vishal/Downloads/Projects/data_science_krishnaik/code/kn_env/lib/python3.11/site-packages (from spacy-curated-transformers<1.0.0,>=0.2.2->en-core-web-trf==3.8.0) (0.1.1)
# Requirement already satisfied: curated-tokenizers<0.1.0,>=0.0.9 in /Users/vishal/Downloads/Projects/data_science_krishnaik/code/kn_env/lib/python3.11/site-packages (from spacy-curated-transformers<1.0.0,>=0.2.2->en-core-web-trf==3.8.0) (0.0.9)
# Requirement already satisfied: torch>=1.12.0 in /Users/vishal/Downloads/Projects/data_science_krishnaik/code/kn_env/lib/python3.11/site-packages (from spacy-curated-transformers<1.0.0,>=0.2.2->en-core-web-trf==3.8.0) (2.7.0)
# Requirement already satisfied: regex>=2022 in /Users/vishal/Downloads/Projects/data_science_krishnaik/code/kn_env/lib/python3.11/site-packages (from curated-tokenizers<0.1.0,>=0.0.9->spacy-curated-transformers<1.0.0,>=0.2.2->en-core-web-trf==3.8.0) (2024.11.6)
# Requirement already satisfied: filelock in /Users/vishal/Downloads/Projects/data_science_krishnaik/code/kn_env/lib/python3.11/site-packages (from torch>=1.12.0->spacy-curated-transformers<1.0.0,>=0.2.2->en-core-web-trf==3.8.0) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /Users/vishal/Downloads/Projects/data_science_krishnaik/code/kn_env/lib/python3.11/site-packages (from torch>=1.12.0->spacy-curated-transformers<1.0.0,>=0.2.2->en-core-web-trf==3.8.0) (4.12.2)
# Requirement already satisfied: sympy>=1.13.3 in /Users/vishal/Downloads/Projects/data_science_krishnaik/code/kn_env/lib/python3.11/site-packages (from torch>=1.12.0->spacy-curated-transformers<1.0.0,>=0.2.2->en-core-web-trf==3.8.0) (1.14.0)
# Requirement already satisfied: networkx in /Users/vishal/Downloads/Projects/data_science_krishnaik/code/kn_env/lib/python3.11/site-packages (from torch>=1.12.0->spacy-curated-transformers<1.0.0,>=0.2.2->en-core-web-trf==3.8.0) (3.4.2)
# Requirement already satisfied: jinja2 in /Users/vishal/Downloads/Projects/data_science_krishnaik/code/kn_env/lib/python3.11/site-packages (from torch>=1.12.0->spacy-curated-transformers<1.0.0,>=0.2.2->en-core-web-trf==3.8.0) (3.1.6)
# Requirement already satisfied: fsspec in /Users/vishal/Downloads/Projects/data_science_krishnaik/code/kn_env/lib/python3.11/site-packages (from torch>=1.12.0->spacy-curated-transformers<1.0.0,>=0.2.2->en-core-web-trf==3.8.0) (2025.5.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /Users/vishal/Downloads/Projects/data_science_krishnaik/code/kn_env/lib/python3.11/site-packages (from sympy>=1.13.3->torch>=1.12.0->spacy-curated-transformers<1.0.0,>=0.2.2->en-core-web-trf==3.8.0) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/vishal/Downloads/Projects/data_science_krishnaik/code/kn_env/lib/python3.11/site-packages (from jinja2->torch>=1.12.0->spacy-curated-transformers<1.0.0,>=0.2.2->en-core-web-trf==3.8.0) (3.0.2)
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_trf')

# %%
# !pip install spacy-transformers
# Out:
# python(59130) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Requirement already satisfied: spacy-transformers in /Users/vishal/Downloads/Projects/data_science_krishnaik/code/kn_env/lib/python3.11/site-packages (1.3.9)
# Requirement already satisfied: spacy<4.1.0,>=3.5.0 in /Users/vishal/Downloads/Projects/data_science_krishnaik/code/kn_env/lib/python3.11/site-packages (from spacy-transformers) (3.8.7)
# Requirement already satisfied: numpy>=1.19.0 in /Users/vishal/Downloads/Projects/data_science_krishnaik/code/kn_env/lib/python3.11/site-packages (from spacy-transformers) (2.1.3)
# Requirement already satisfied: transformers<4.50.0,>=3.4.0 in /Users/vishal/Downloads/Projects/data_science_krishnaik/code/kn_env/lib/python3.11/site-packages (from spacy-transformers) (4.49.0)
# Requirement already satisfied: torch>=1.8.0 in /Users/vishal/Downloads/Projects/data_science_krishnaik/code/kn_env/lib/python3.11/site-packages (from spacy-transformers) (2.7.0)
# Requirement already satisfied: srsly<3.0.0,>=2.4.0 in /Users/vishal/Downloads/Projects/data_science_krishnaik/code/kn_env/lib/python3.11/site-packages (from spacy-transformers) (2.5.1)
# Requirement already satisfied: spacy-alignments<1.0.0,>=0.7.2 in /Users/vishal/Downloads/Projects/data_science_krishnaik/code/kn_env/lib/python3.11/site-packages (from spacy-transformers) (0.9.1)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /Users/vishal/Downloads/Projects/data_science_krishnaik/code/kn_env/lib/python3.11/site-packages (from spacy<4.1.0,>=3.5.0->spacy-transformers) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /Users/vishal/Downloads/Projects/data_science_krishnaik/code/kn_env/lib/python3.11/site-packages (from spacy<4.1.0,>=3.5.0->spacy-transformers) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /Users/vishal/Downloads/Projects/data_science_krishnaik/code/kn_env/lib/python3.11/site-packages (from spacy<4.1.0,>=3.5.0->spacy-transformers) (1.0.13)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /Users/vishal/Downloads/Projects/data_science_krishnaik/code/kn_env/lib/python3.11/site-packages (from spacy<4.1.0,>=3.5.0->spacy-transformers) (2.0.11)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /Users/vishal/Downloads/Projects/data_science_krishnaik/code/kn_env/lib/python3.11/site-packages (from spacy<4.1.0,>=3.5.0->spacy-transformers) (3.0.10)
# Requirement already satisfied: thinc<8.4.0,>=8.3.4 in /Users/vishal/Downloads/Projects/data_science_krishnaik/code/kn_env/lib/python3.11/site-packages (from spacy<4.1.0,>=3.5.0->spacy-transformers) (8.3.6)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /Users/vishal/Downloads/Projects/data_science_krishnaik/code/kn_env/lib/python3.11/site-packages (from spacy<4.1.0,>=3.5.0->spacy-transformers) (1.1.3)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /Users/vishal/Downloads/Projects/data_science_krishnaik/code/kn_env/lib/python3.11/site-packages (from spacy<4.1.0,>=3.5.0->spacy-transformers) (2.0.10)
# Requirement already satisfied: weasel<0.5.0,>=0.1.0 in /Users/vishal/Downloads/Projects/data_science_krishnaik/code/kn_env/lib/python3.11/site-packages (from spacy<4.1.0,>=3.5.0->spacy-transformers) (0.4.1)
# Requirement already satisfied: typer<1.0.0,>=0.3.0 in /Users/vishal/Downloads/Projects/data_science_krishnaik/code/kn_env/lib/python3.11/site-packages (from spacy<4.1.0,>=3.5.0->spacy-transformers) (0.16.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /Users/vishal/Downloads/Projects/data_science_krishnaik/code/kn_env/lib/python3.11/site-packages (from spacy<4.1.0,>=3.5.0->spacy-transformers) (4.67.1)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /Users/vishal/Downloads/Projects/data_science_krishnaik/code/kn_env/lib/python3.11/site-packages (from spacy<4.1.0,>=3.5.0->spacy-transformers) (2.32.3)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /Users/vishal/Downloads/Projects/data_science_krishnaik/code/kn_env/lib/python3.11/site-packages (from spacy<4.1.0,>=3.5.0->spacy-transformers) (2.11.5)
# Requirement already satisfied: jinja2 in /Users/vishal/Downloads/Projects/data_science_krishnaik/code/kn_env/lib/python3.11/site-packages (from spacy<4.1.0,>=3.5.0->spacy-transformers) (3.1.6)
# Requirement already satisfied: setuptools in /Users/vishal/Downloads/Projects/data_science_krishnaik/code/kn_env/lib/python3.11/site-packages (from spacy<4.1.0,>=3.5.0->spacy-transformers) (75.5.0)
# Requirement already satisfied: packaging>=20.0 in /Users/vishal/Downloads/Projects/data_science_krishnaik/code/kn_env/lib/python3.11/site-packages (from spacy<4.1.0,>=3.5.0->spacy-transformers) (24.2)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /Users/vishal/Downloads/Projects/data_science_krishnaik/code/kn_env/lib/python3.11/site-packages (from spacy<4.1.0,>=3.5.0->spacy-transformers) (3.5.0)
# Requirement already satisfied: filelock in /Users/vishal/Downloads/Projects/data_science_krishnaik/code/kn_env/lib/python3.11/site-packages (from torch>=1.8.0->spacy-transformers) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /Users/vishal/Downloads/Projects/data_science_krishnaik/code/kn_env/lib/python3.11/site-packages (from torch>=1.8.0->spacy-transformers) (4.12.2)
# Requirement already satisfied: sympy>=1.13.3 in /Users/vishal/Downloads/Projects/data_science_krishnaik/code/kn_env/lib/python3.11/site-packages (from torch>=1.8.0->spacy-transformers) (1.14.0)
# Requirement already satisfied: networkx in /Users/vishal/Downloads/Projects/data_science_krishnaik/code/kn_env/lib/python3.11/site-packages (from torch>=1.8.0->spacy-transformers) (3.4.2)
# Requirement already satisfied: fsspec in /Users/vishal/Downloads/Projects/data_science_krishnaik/code/kn_env/lib/python3.11/site-packages (from torch>=1.8.0->spacy-transformers) (2025.5.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.26.0 in /Users/vishal/Downloads/Projects/data_science_krishnaik/code/kn_env/lib/python3.11/site-packages (from transformers<4.50.0,>=3.4.0->spacy-transformers) (0.32.2)
# Requirement already satisfied: pyyaml>=5.1 in /Users/vishal/Downloads/Projects/data_science_krishnaik/code/kn_env/lib/python3.11/site-packages (from transformers<4.50.0,>=3.4.0->spacy-transformers) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /Users/vishal/Downloads/Projects/data_science_krishnaik/code/kn_env/lib/python3.11/site-packages (from transformers<4.50.0,>=3.4.0->spacy-transformers) (2024.11.6)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /Users/vishal/Downloads/Projects/data_science_krishnaik/code/kn_env/lib/python3.11/site-packages (from transformers<4.50.0,>=3.4.0->spacy-transformers) (0.21.1)
# Requirement already satisfied: safetensors>=0.4.1 in /Users/vishal/Downloads/Projects/data_science_krishnaik/code/kn_env/lib/python3.11/site-packages (from transformers<4.50.0,>=3.4.0->spacy-transformers) (0.5.3)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.2 in /Users/vishal/Downloads/Projects/data_science_krishnaik/code/kn_env/lib/python3.11/site-packages (from huggingface-hub<1.0,>=0.26.0->transformers<4.50.0,>=3.4.0->spacy-transformers) (1.1.2)
# Requirement already satisfied: language-data>=1.2 in /Users/vishal/Downloads/Projects/data_science_krishnaik/code/kn_env/lib/python3.11/site-packages (from langcodes<4.0.0,>=3.2.0->spacy<4.1.0,>=3.5.0->spacy-transformers) (1.3.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/vishal/Downloads/Projects/data_science_krishnaik/code/kn_env/lib/python3.11/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<4.1.0,>=3.5.0->spacy-transformers) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /Users/vishal/Downloads/Projects/data_science_krishnaik/code/kn_env/lib/python3.11/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<4.1.0,>=3.5.0->spacy-transformers) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /Users/vishal/Downloads/Projects/data_science_krishnaik/code/kn_env/lib/python3.11/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<4.1.0,>=3.5.0->spacy-transformers) (0.4.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/vishal/Downloads/Projects/data_science_krishnaik/code/kn_env/lib/python3.11/site-packages (from requests<3.0.0,>=2.13.0->spacy<4.1.0,>=3.5.0->spacy-transformers) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /Users/vishal/Downloads/Projects/data_science_krishnaik/code/kn_env/lib/python3.11/site-packages (from requests<3.0.0,>=2.13.0->spacy<4.1.0,>=3.5.0->spacy-transformers) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/vishal/Downloads/Projects/data_science_krishnaik/code/kn_env/lib/python3.11/site-packages (from requests<3.0.0,>=2.13.0->spacy<4.1.0,>=3.5.0->spacy-transformers) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/vishal/Downloads/Projects/data_science_krishnaik/code/kn_env/lib/python3.11/site-packages (from requests<3.0.0,>=2.13.0->spacy<4.1.0,>=3.5.0->spacy-transformers) (2025.4.26)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /Users/vishal/Downloads/Projects/data_science_krishnaik/code/kn_env/lib/python3.11/site-packages (from sympy>=1.13.3->torch>=1.8.0->spacy-transformers) (1.3.0)
# Requirement already satisfied: blis<1.4.0,>=1.3.0 in /Users/vishal/Downloads/Projects/data_science_krishnaik/code/kn_env/lib/python3.11/site-packages (from thinc<8.4.0,>=8.3.4->spacy<4.1.0,>=3.5.0->spacy-transformers) (1.3.0)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /Users/vishal/Downloads/Projects/data_science_krishnaik/code/kn_env/lib/python3.11/site-packages (from thinc<8.4.0,>=8.3.4->spacy<4.1.0,>=3.5.0->spacy-transformers) (0.1.5)
# Requirement already satisfied: click>=8.0.0 in /Users/vishal/Downloads/Projects/data_science_krishnaik/code/kn_env/lib/python3.11/site-packages (from typer<1.0.0,>=0.3.0->spacy<4.1.0,>=3.5.0->spacy-transformers) (8.2.1)
# Requirement already satisfied: shellingham>=1.3.0 in /Users/vishal/Downloads/Projects/data_science_krishnaik/code/kn_env/lib/python3.11/site-packages (from typer<1.0.0,>=0.3.0->spacy<4.1.0,>=3.5.0->spacy-transformers) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in /Users/vishal/Downloads/Projects/data_science_krishnaik/code/kn_env/lib/python3.11/site-packages (from typer<1.0.0,>=0.3.0->spacy<4.1.0,>=3.5.0->spacy-transformers) (14.0.0)
# Requirement already satisfied: cloudpathlib<1.0.0,>=0.7.0 in /Users/vishal/Downloads/Projects/data_science_krishnaik/code/kn_env/lib/python3.11/site-packages (from weasel<0.5.0,>=0.1.0->spacy<4.1.0,>=3.5.0->spacy-transformers) (0.21.1)
# Requirement already satisfied: smart-open<8.0.0,>=5.2.1 in /Users/vishal/Downloads/Projects/data_science_krishnaik/code/kn_env/lib/python3.11/site-packages (from weasel<0.5.0,>=0.1.0->spacy<4.1.0,>=3.5.0->spacy-transformers) (7.1.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/vishal/Downloads/Projects/data_science_krishnaik/code/kn_env/lib/python3.11/site-packages (from jinja2->spacy<4.1.0,>=3.5.0->spacy-transformers) (3.0.2)
# Requirement already satisfied: marisa-trie>=1.1.0 in /Users/vishal/Downloads/Projects/data_science_krishnaik/code/kn_env/lib/python3.11/site-packages (from language-data>=1.2->langcodes<4.0.0,>=3.2.0->spacy<4.1.0,>=3.5.0->spacy-transformers) (1.2.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /Users/vishal/Downloads/Projects/data_science_krishnaik/code/kn_env/lib/python3.11/site-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy<4.1.0,>=3.5.0->spacy-transformers) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /Users/vishal/Downloads/Projects/data_science_krishnaik/code/kn_env/lib/python3.11/site-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy<4.1.0,>=3.5.0->spacy-transformers) (2.18.0)
# Requirement already satisfied: wrapt in /Users/vishal/Downloads/Projects/data_science_krishnaik/code/kn_env/lib/python3.11/site-packages (from smart-open<8.0.0,>=5.2.1->weasel<0.5.0,>=0.1.0->spacy<4.1.0,>=3.5.0->spacy-transformers) (1.17.2)
# Requirement already satisfied: mdurl~=0.1 in /Users/vishal/Downloads/Projects/data_science_krishnaik/code/kn_env/lib/python3.11/site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy<4.1.0,>=3.5.0->spacy-transformers) (0.1.2)

# %%
# !python -m spacy download en_core_web_trf

# Or for other models
# !python -m spacy download en_core_web_md
# !python -m spacy download en_core_web_sm
#python -m spacy download en_core_web_lg
# Out:
# python(59243) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Collecting en-core-web-trf==3.8.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_trf-3.8.0/en_core_web_trf-3.8.0-py3-none-any.whl (457.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 457.4/457.4 MB 5.4 MB/s eta 0:00:0000:0100:03
# Requirement already satisfied: spacy-curated-transformers<1.0.0,>=0.2.2 in /Users/vishal/Downloads/Projects/data_science_krishnaik/code/kn_env/lib/python3.11/site-packages (from en-core-web-trf==3.8.0) (0.3.0)
# Requirement already satisfied: curated-transformers<0.2.0,>=0.1.0 in /Users/vishal/Downloads/Projects/data_science_krishnaik/code/kn_env/lib/python3.11/site-packages (from spacy-curated-transformers<1.0.0,>=0.2.2->en-core-web-trf==3.8.0) (0.1.1)
# Requirement already satisfied: curated-tokenizers<0.1.0,>=0.0.9 in /Users/vishal/Downloads/Projects/data_science_krishnaik/code/kn_env/lib/python3.11/site-packages (from spacy-curated-transformers<1.0.0,>=0.2.2->en-core-web-trf==3.8.0) (0.0.9)
# Requirement already satisfied: torch>=1.12.0 in /Users/vishal/Downloads/Projects/data_science_krishnaik/code/kn_env/lib/python3.11/site-packages (from spacy-curated-transformers<1.0.0,>=0.2.2->en-core-web-trf==3.8.0) (2.7.0)
# Requirement already satisfied: regex>=2022 in /Users/vishal/Downloads/Projects/data_science_krishnaik/code/kn_env/lib/python3.11/site-packages (from curated-tokenizers<0.1.0,>=0.0.9->spacy-curated-transformers<1.0.0,>=0.2.2->en-core-web-trf==3.8.0) (2024.11.6)
# Requirement already satisfied: filelock in /Users/vishal/Downloads/Projects/data_science_krishnaik/code/kn_env/lib/python3.11/site-packages (from torch>=1.12.0->spacy-curated-transformers<1.0.0,>=0.2.2->en-core-web-trf==3.8.0) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /Users/vishal/Downloads/Projects/data_science_krishnaik/code/kn_env/lib/python3.11/site-packages (from torch>=1.12.0->spacy-curated-transformers<1.0.0,>=0.2.2->en-core-web-trf==3.8.0) (4.12.2)
# Requirement already satisfied: sympy>=1.13.3 in /Users/vishal/Downloads/Projects/data_science_krishnaik/code/kn_env/lib/python3.11/site-packages (from torch>=1.12.0->spacy-curated-transformers<1.0.0,>=0.2.2->en-core-web-trf==3.8.0) (1.14.0)
# Requirement already satisfied: networkx in /Users/vishal/Downloads/Projects/data_science_krishnaik/code/kn_env/lib/python3.11/site-packages (from torch>=1.12.0->spacy-curated-transformers<1.0.0,>=0.2.2->en-core-web-trf==3.8.0) (3.4.2)
# Requirement already satisfied: jinja2 in /Users/vishal/Downloads/Projects/data_science_krishnaik/code/kn_env/lib/python3.11/site-packages (from torch>=1.12.0->spacy-curated-transformers<1.0.0,>=0.2.2->en-core-web-trf==3.8.0) (3.1.6)
# Requirement already satisfied: fsspec in /Users/vishal/Downloads/Projects/data_science_krishnaik/code/kn_env/lib/python3.11/site-packages (from torch>=1.12.0->spacy-curated-transformers<1.0.0,>=0.2.2->en-core-web-trf==3.8.0) (2025.5.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /Users/vishal/Downloads/Projects/data_science_krishnaik/code/kn_env/lib/python3.11/site-packages (from sympy>=1.13.3->torch>=1.12.0->spacy-curated-transformers<1.0.0,>=0.2.2->en-core-web-trf==3.8.0) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/vishal/Downloads/Projects/data_science_krishnaik/code/kn_env/lib/python3.11/site-packages (from jinja2->torch>=1.12.0->spacy-curated-transformers<1.0.0,>=0.2.2->en-core-web-trf==3.8.0) (3.0.2)
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_trf')
# python(59285) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Collecting en-core-web-md==3.8.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_md-3.8.0/en_core_web_md-3.8.0-py3-none-any.whl (33.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 33.5/33.5 MB 5.6 MB/s eta 0:00:0000:0100:01
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_md')
# python(59288) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Collecting en-core-web-sm==3.8.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.8.0/en_core_web_sm-3.8.0-py3-none-any.whl (12.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.8/12.8 MB 5.5 MB/s eta 0:00:00a 0:00:01
# Installing collected packages: en-core-web-sm
# Successfully installed en-core-web-sm-3.8.0
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')

# %%
import spacy
import torch

# %%
nlp = spacy.load("en_core_web_trf")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 nlp = spacy.load("en_core_web_trf")
#
# File ~/Downloads/Projects/data_science_krishnaik/code/kn_env/lib/python3.11/site-packages/spacy/__init__.py:52, in load(name, vocab, disable, enable, exclude, config)
#      28 def load(
#      29     name: Union[str, Path],
#      30     *,
#    (...)
#      35     config: Union[Dict[str, Any], Config] = util.SimpleFrozenDict(),
#      36 ) -> Language:
#      37     """Load a spaCy model from an installed package or a local path.
#      38
#      39     name (str): Package name or model path.
#    (...)
#      50     RETURNS (Language): The loaded nlp object.
#      51     """
# ---> 52     return util.load_model(
#      53         name,
#      54         vocab=vocab,
#      55         disable=disable,
#      56         enable=enable,
#      57         exclude=exclude,
#      58         config=config,
#      59     )
#
# File ~/Downloads/Projects/data_science_krishnaik/code/kn_env/lib/python3.11/site-packages/spacy/util.py:477, in load_model(name, vocab, disable, enable, exclude, config)
#     475     return get_lang_class(name.replace("blank:", ""))()
#     476 if is_package(name):  # installed as package
# --> 477     return load_model_from_package(name, **kwargs)  # type: ignore[arg-type]
#     478 if Path(name).exists():  # path to model data directory
#     479     return load_model_from_path(Path(name), **kwargs)  # type: ignore[arg-type]
#
# File ~/Downloads/Projects/data_science_krishnaik/code/kn_env/lib/python3.11/site-packages/spacy/util.py:513, in load_model_from_package(name, vocab, disable, enable, exclude, config)
#     496 """Load a model from an installed package.
#     497
#     498 name (str): The package name.
#    (...)
#     510 RETURNS (Language): The loaded nlp object.
#     511 """
#     512 cls = importlib.import_module(name)
# --> 513 return cls.load(vocab=vocab, disable=disable, enable=enable, exclude=exclude, config=config)
#
# File ~/Downloads/Projects/data_science_krishnaik/code/kn_env/lib/python3.11/site-packages/en_core_web_trf/__init__.py:10, in load(**overrides)
#       9 def load(**overrides):
# ---> 10     return load_model_from_init_py(__file__, **overrides)
#
# File ~/Downloads/Projects/data_science_krishnaik/code/kn_env/lib/python3.11/site-packages/spacy/util.py:694, in load_model_from_init_py(init_file, vocab, disable, enable, exclude, config)
#     692 if not model_path.exists():
#     693     raise IOError(Errors.E052.format(path=data_path))
# --> 694 return load_model_from_path(
#     695     data_path,
#     696     vocab=vocab,
#     697     meta=meta,
#     698     disable=disable,
#     699     enable=enable,
#     700     exclude=exclude,
#     701     config=config,
#     702 )
#
# File ~/Downloads/Projects/data_science_krishnaik/code/kn_env/lib/python3.11/site-packages/spacy/util.py:551, in load_model_from_path(model_path, meta, vocab, disable, enable, exclude, config)
#     549 overrides = dict_to_dot(config, for_overrides=True)
#     550 config = load_config(config_path, overrides=overrides)
# --> 551 nlp = load_model_from_config(
#     552     config,
#     553     vocab=vocab,
#     554     disable=disable,
#     555     enable=enable,
#     556     exclude=exclude,
#     557     meta=meta,
#     558 )
#     559 return nlp.from_disk(model_path, exclude=exclude, overrides=overrides)
#
# File ~/Downloads/Projects/data_science_krishnaik/code/kn_env/lib/python3.11/site-packages/spacy/util.py:599, in load_model_from_config(config, meta, vocab, disable, enable, exclude, auto_fill, validate)
#     596 # This will automatically handle all codes registered via the languages
#     597 # registry, including custom subclasses provided via entry points
#     598 lang_cls = get_lang_class(nlp_config["lang"])
# --> 599 nlp = lang_cls.from_config(
#     600     config,
#     601     vocab=vocab,
#     602     disable=disable,
#     603     enable=enable,
#     604     exclude=exclude,
#     605     auto_fill=auto_fill,
#     606     validate=validate,
#     607     meta=meta,
#     608 )
#     609 return nlp
#
# File ~/Downloads/Projects/data_science_krishnaik/code/kn_env/lib/python3.11/site-packages/spacy/language.py:1893, in Language.from_config(cls, config, vocab, disable, enable, exclude, meta, auto_fill, validate)
#    1890     factory = pipe_cfg.pop("factory")
#    1891     # The pipe name (key in the config) here is the unique name
#    1892     # of the component, not necessarily the factory
# -> 1893     nlp.add_pipe(
#    1894         factory,
#    1895         name=pipe_name,
#    1896         config=pipe_cfg,
#    1897         validate=validate,
#    1898         raw_config=raw_config,
#    1899     )
#    1900 else:
#    1901     assert "source" in pipe_cfg
#
# File ~/Downloads/Projects/data_science_krishnaik/code/kn_env/lib/python3.11/site-packages/spacy/language.py:825, in Language.add_pipe(self, factory_name, name, before, after, first, last, source, config, raw_config, validate)
#     821     pipe_component, factory_name = self.create_pipe_from_source(
#     822         factory_name, source, name=name
#     823     )
#     824 else:
# --> 825     pipe_component = self.create_pipe(
#     826         factory_name,
#     827         name=name,
#     828         config=config,
#     829         raw_config=raw_config,
#     830         validate=validate,
#     831     )
#     832 pipe_index = self._get_pipe_index(before, after, first, last)
#     833 self._pipe_meta[name] = self.get_factory_meta(factory_name)
#
# File ~/Downloads/Projects/data_science_krishnaik/code/kn_env/lib/python3.11/site-packages/spacy/language.py:694, in Language.create_pipe(self, factory_name, name, config, raw_config, validate)
#     686 if not self.has_factory(factory_name):
#     687     err = Errors.E002.format(
#     688         name=factory_name,
#     689         opts=", ".join(self.factory_names),
#    (...)
#     692         lang_code=self.lang,
#     693     )
# --> 694     raise ValueError(err)
#     695 pipe_meta = self.get_factory_meta(factory_name)
#     696 # This is unideal, but the alternative would mean you always need to
#     697 # specify the full config settings, which is not really viable.
#
# ValueError: [E002] Can't find factory for 'curated_transformer' for language English (en). This usually happens when spaCy calls `nlp.create_pipe` with a custom component name that's not registered on the current language class. If you're using a custom component, make sure you've added the decorator `@Language.component` (for function components) or `@Language.factory` (for class components).
#
# Available factories: merge_noun_chunks, merge_entities, merge_subtokens, en.lemmatizer

# %%
# !pip install -q kaggle
# !kaggle datasets download -d clmentbisaillon/fake-and-real-news-dataset
# Out:
# Traceback (most recent call last):
#   File "/Users/vishal/Downloads/Projects/data_science_krishnaik/code/kn_env/bin/kaggle", line 8, in <module>
#     sys.exit(main())
#              ^^^^^^
#   File "/Users/vishal/Downloads/Projects/data_science_krishnaik/code/kn_env/lib/python3.11/site-packages/kaggle/cli.py", line 68, in main
#     out = args.func(**command_args)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/vishal/Downloads/Projects/data_science_krishnaik/code/kn_env/lib/python3.11/site-packages/kaggle/api/kaggle_api_extended.py", line 1741, in dataset_download_cli
#     with self.build_kaggle_client() as kaggle:
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/vishal/Downloads/Projects/data_science_krishnaik/code/kn_env/lib/python3.11/site-packages/kaggle/api/kaggle_api_extended.py", line 688, in build_kaggle_client
#     username=self.config_values['username'],
#              ~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^
# KeyError: 'username'
